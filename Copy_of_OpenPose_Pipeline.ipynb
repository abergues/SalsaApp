# %% [markdown]
# <a href="https://colab.research.google.com/github/abergues/SalsaApp/blob/eero/Copy_of_OpenPose_Pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Running preprocessing with OpenPose
#
# Single file to run
#
#
# *   VideoProcessing.ipynb
# *   AnnotationFile.ipynb
# *  Parsing-Openpose-Annotation.ipynb

# %%
# libraries needed from outside
import os
from os import mkdir
from os.path import exists, join, basename, splitext
import sys
import glob                       # help for finding files
from re import split              # regular expression string splitter
import subprocess                 #subprocess wraps around regular os commands
import shutil                     # used for copying files in the os.

from google.colab import drive
drive.mount('/content/gdrive')
 
if os.path.isdir('/content/gdrive/MyDrive'):     # Ana
  google_drive_path = '/content/gdrive/MyDrive'
if os.path.isdir('/content/gdrive/MyDrive/DSR'):  # Eero. ipython can deal with MyDrive, 
  # but some bash commands require the space in "My Drive" to work.  and some fail.
  # I believe this has to do with what kind of " " '' one is using, as they must not be mixed. 
  google_drive_path = '/content/gdrive/MyDrive/DSR' 
else:
  print("There is a problem google_drive_path.")

root_path   = os.path.join(google_drive_path ,  "DanceApp")  
script_path = "/content/gdrive/MyDrive/DSR/2021-DSR-Porfolio/python_scripts"
#one cannot add items to sys.path that have a space in them. so script path must
#the same for Ana and Eero.  Eero has now added a link from his DSR to Ana's 2021-DSR-Porfolio/
#script_path = os.path.join(google_drive_path , "2021-DSR-Porfolio/python_scripts")
print("Using ", root_path, " as root_path")
# here = os.getcwd()
# print(here)
# print(sys.path)
# sys.path = ['', '/content', '/env/python', '/usr/lib/python37.zip', '/usr/lib/python3.7', '/usr/lib/python3.7/lib-dynload', '/usr/local/lib/python3.7/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.7/dist-packages/IPython/extensions', '/root/.ipython']
def check_path(x):
  if os.path.isdir(x):
    print("Using", x )
  else:
    print("Problem: There was no ", x)  # No error keeps running

def stop_if_no_path(x):
  if os.path.isdir(x):
    print("Using", x )
  else:
    raise Exception("Problem: There was no ", x)  # Throws and error and stops
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Using  /content/gdrive/MyDrive/DSR/DanceApp  as root_path

# %%
check_path(root_path)
check_path(script_path)
# Out:
# Using /content/gdrive/MyDrive/DSR/DanceApp
# Using /content/gdrive/MyDrive/DSR/2021-DSR-Porfolio/python_scripts

# %% [markdown]
# ## Build OpenPose

# %%
# Path and variables to build OpenPose
git_repo_url = 'https://github.com/CMU-Perceptual-Computing-Lab/openpose.git'
project_name = splitext(basename(git_repo_url))[0]
if not exists(project_name):                                    ## This saves Lots of time when rerunning the whole notebook.
  # see: https://github.com/CMU-Perceptual-Computing-Lab/openpose/issues/949
  # install new CMake becaue of CUDA10
  # !wget -q https://cmake.org/files/v3.13/cmake-3.13.0-Linux-x86_64.tar.gz
  # !tar xfz cmake-3.13.0-Linux-x86_64.tar.gz --strip-components=1 -C /usr/local
  # clone openpose
  # !git clone -q --depth 1 $git_repo_url
  # !sed -i 's/execute_process(COMMAND git checkout master WORKING_DIRECTORY ${CMAKE_SOURCE_DIR}\/3rdparty\/caffe)/execute_process(COMMAND git checkout f019d0dfe86f49d1140961f8c7dec22130c83154 WORKING_DIRECTORY ${CMAKE_SOURCE_DIR}\/3rdparty\/caffe)/g' openpose/CMakeLists.txt
  # install system dependencies
  # !apt-get -qq install -y libatlas-base-dev libprotobuf-dev libleveldb-dev libsnappy-dev libhdf5-serial-dev protobuf-compiler libgflags-dev libgoogle-glog-dev liblmdb-dev opencl-headers ocl-icd-opencl-dev libviennacl-dev
  # install python dependencies
  # !pip install -q youtube-dl
  # build openpose
  # !cd openpose && rm -rf build || true && mkdir build && cd build && cmake .. && make -j`nproc`
# !ffprobe -v 0 -of csv=p=0 -select_streams v:0 -show_entries stream=r_frame_rate $video 
# Function to run OpenPose TODO, add this function to python script

# %% [markdown]
# ## Define Functions

# %%
def load_video_run_openpose(video):
  #requires that video_id and connected variables are set.   
  # Check for the speed of the video
  frames_per_s = default_fps            # if everything fails there is a default value
  if not os.path.isfile(video):
    print("There video is missing: \n ", video)
  else:
    print("OpenPose will now analyse \n", video)

  print(os.getcwd())
  text = !ffprobe -v 0 -of csv=p=0 -select_streams v:0 -show_entries stream=r_frame_rate $video 
  print(text)
  #frames, seconds = text.split("/")
  frames, seconds = text[0].split("/")
  frames_per_s = int(frames) / int(seconds)
  
  print("Number of frames per second: ", frames_per_s)
  print("\n")
  if frames_per_s > 20:
    multiplikator_for_images_per_second = frames_per_s / save_frames_per_second
  else:
    multiplikator_for_images_per_second = default_fps / save_frames_per_second
  
  # cut the parts of video that we cannot use
  # !ffmpeg -y -loglevel info -i "input_original/youtube.mp4" -ss $start_mmss -t $duration "input_original/video.mp4"
  
  # detect poses
  print(f"Video for Openpose {video}") 
  op_video = output_op_dir + "/openpose.avi"
  op_json = output_op_dir + "/json"

  if not os.path.exists(op_json): 
    # !mkdir $op_json

  # !cd openpose && ./build/examples/openpose/openpose.bin --video $video --write_json $op_json --display 0 --number_people_max 1 --write_video $op_video

  # convert the result into MP4
  print(" ")
  print("============================== ")
  print("Converting the stickfigure video to mp4 ")
  print(" ")

  op_video_mp4 = output_op_dir + "/openpose.mp4"
  # !ffmpeg -y -loglevel info -i $op_video $op_video_mp4
  # removing avi
  if os.path.isfile(op_video): 
    os.remove(op_video)
  else:
    print("Something went wrong, as there was no output video from Openpose.")

  print(" ")
  print("Creating single frame images ")
  print("============================== ")
  print(" ")

  ## Get only a selection of frames for labeling
  ## TODO: the numbering should match the numbering of the json files
  # save_frames_per_second = save_frames_per_second 
  # Optional to get the frames with the stick figures
  # !ffmpeg -y -loglevel info -i "output_op/$clip_name/openpose.mp4" -s $size_of_single_frame -r $save_frames_per_second -f image2 "output_op/$clip_name/frame-%06d.jpeg" 

  print(" ")
  print("============================== ")  
# print(video)
# text = subprocess.getoutput('ffprobe -v 0 -of csv=p=0 -select_streams v:0 -show_entries stream=r_frame_rate $video') 
# text.split("/")
#frames, seconds = 
# frames_per_s = int(frames) / int(seconds)
# frames_per_s  



check_path(script_path)
print(os.listdir(script_path))

if not script_path in sys.path:    #otherwise will add anew with every run of script.
   sys.path.append(script_path)
   print("Added script_path to search path.")

# from videoprocessing import delete_outputs, load_video_run_openpose
import VideoProcessing as vp
# Out:
# Using /content/gdrive/MyDrive/DSR/2021-DSR-Porfolio/python_scripts
# ['__pycache__', 'Test.py', 'VideoProcessing.py', 'utils.py', '__init__.py', 'AnnotationFile.py', 'AnnotationFile_t.py', 'videoprocessing_old.py', 'Parsing-Openpose-Annotation.py']

# %%
def resize_video(new_height, clip_name, src_folder):
    video_name, video_ext = splitext(clip_name)
    print("clip_name: ", clip_name)
    print("video_name: ", video_name, " extention: ", video_ext)
    print(new_height)
    resize_output_dir = os.path.join(root_path, src_folder ,"h" + str(new_height))
    video_out = resize_output_dir + "/" + video_name + "_h" + str(new_height) + video_ext
    print(video_out)
    video_in = video

    if os.path.isfile(video_in):
      print("Found the video_in")
    else:
      print("The video_in does not exist.")
      # raise Exception("No input video file")

    if not os.path.isdir(resize_output_dir):
      os.mkdir(resize_output_dir)
      print("Created a folder for resized video output:", src_folder, "/h",str(new_height) )
    else:
      print("Folder for resized video output:", src_folder, "/h",str(new_height) )
    
    if os.path.isfile(video_out):
      print("The video has been resized previously")
    else:
      print("The video is being resized, which takes often 10 min or more.")
      # !ffmpeg -i $video_in -vf scale=-1:$new_height $video_out
    return video_out

# %%
# here = os.getcwd()
# print(here)
# print(sys.path)
# sys.path = ['', '/content', '/env/python', '/usr/lib/python37.zip', '/usr/lib/python3.7', '/usr/lib/python3.7/lib-dynload', '/usr/local/lib/python3.7/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.7/dist-packages/IPython/extensions', '/root/.ipython']

# %%
def delete_outputs(video_id, root_path, output_dir):
    # delete output_files from Openpose if they were already created
    print("Deleting old output files from the ", output_dir, video_id, " folder")
    # create a list of files to delete
    delete_files = glob.glob(os.path.join(root_path, output_dir, video_id, "json", "*.json"))
    delete_files.extend(glob.glob(os.path.join(root_path, output_dir, video_id, "*.mp4")))
    delete_files.extend(glob.glob(os.path.join(root_path, output_dir, video_id, "*.MOV")))
    # delete_files.extend(glob.glob(os.path.join(root_path, "output_op", clip_name, "*.avi")))
    # print("avi: ", delete_files[-1:])
    [os.remove(x) for x in delete_files]

    print("\n Now the output folder contains only these files:")
    print(glob.glob(os.path.join(root_path, output_dir, video_id, "json", "*.json")))

# %%
def rename_json(video_id, root_path, output_dir):
    ## Better names for JSON
    # find all json files and change the name
    # os.chdir(original_working_dir)
    print(os.getcwd())
    paths_json = glob.glob(os.path.join(root_path, output_dir, video_id, "json", "*.json"))
    paths_json = sorted(paths_json, reverse=True)
    print("there are ", len(paths_json), " json files to rename")

    for old_file in paths_json:
        frame_number = old_file[-21:-15]  # counting backwards is safest, because folder names change
        # print(f"Frame {frame_number}")
        # print(f"Old name {old_file}")
        new_file_name = os.path.join(root_path, output_dir, video_id, "json") + "/frame-" + frame_number + ".json"
        # print(f"New name {new_file_name}")
        os.rename(old_file, new_file_name)

    print(" ")
    print("json are renamed")
    print("============================== ")

    # delete old names
    # [os.remove(x) for x in paths_json]
    print(" ")

# %%
# ??vp.rename_json()

# %% [markdown]
# # Main Part

# %%
# Global variables with Paths for all the functions
size_of_single_frame = "640x360"
save_frames_per_second = 5  # the number of jpgs per second
default_fps = 30     # the default frames per second of the videos, 
                     # which often is wrong  
                     # and needs to be corrected after the download
                     # so that the json and jpg files match each other.
video_size = "h920"                     
output_dir = "output_op_1p"
input_dir = "1P_input_original"

video_list = [ 
 '1p_Artur_05122021_chreo1.mp4',
 '1p_Earl_05122021_choreo1_flipped_lr.mp4',
 '1p_Eero_1_05122021_choreo1.mp4',
 '1p_Eero_4_05122021_choreo1.mp4',
 '1p_Eero_6_05122021_choreo1.mp4',
 '1p_Eero_7_05122021_choreo1.mp4',
 '1p_Dirk_choreo1_04.12.2021.mp4',
 '1p_Heidi_07122021_choreo1_-turns.MOV',
 '1p_JonathanB_05122021_choreo1.MOV',
 '1P-Person1-whole.mp4',
 '1p_Raquelinha_05122021_choreo1.mp4',
 '1p_sarah_salsa_basics_choreo1.mp4',
 '1p_Stef_1_05122021_Choreo1.mp4',
 '1p_Stef_2_05122021_Choreo1.mp4',
 '1p_Stef_3_05122021_chroeo1.mp4',
]

input_video_fullsize_dir = os.path.join(root_path, input_dir) 
input_video_resized_dir = os.path.join(root_path, input_dir, video_size)
check_path(input_video_fullsize_dir)
check_path(input_video_resized_dir)

for i in range(len(video_list)):
  clip_name = video_list[i]
  video_id = splitext(video_list[i])[0]
  video_name, video_ext = splitext(video)
  video = os.path.join(input_video_fullsize_dir, clip_name)
  video_resized = input_video_resized_dir + "/" + video_id + '_' + video_size + video_ext 
  print("video fullsize: ", video)
  print("video_resized: ", video_resized)
  print(video_ext)

  # Video Processing and OpenPose  
  from pathlib import Path as P
  output_main = os.path.join(root_path, output_dir)
  if not os.path.isdir(output_main): 
    # !mkdir $output_main
  
  output_op_dir = os.path.join(output_main, video_id)
  if not os.path.isdir(output_op_dir): 
    # !mkdir $output_op_dir
  
  print("Processing video", clip_name)
  
  # video_resized = resize_video(920, clip_name=clip_name, src_folder="1P_input_original")
  
  delete_outputs(video_id=video_id, root_path=root_path, output_dir=output_dir)
  load_video_run_openpose(video=video_resized)
  rename_json(video_id, root_path=root_path, output_dir=output_dir)

  # Creating the annotation file
  # !cp $script_path/AnnotationFile.py .
  # !python AnnotationFile.py $output_op_dir
  
  # Parsing JSON and adding information from annotation
  # Anot_file = output_op_dir + "/Annotation.json" 
  # !cp $script_path/Parsing-Openpose-Annotation.py .
  # !python Parsing-Openpose-Annotation.py $video_id $output_op_dir $Anot_file
# Out:
# Using /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original
# Using /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920
# video fullsize:  /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/1p_Artur_05122021_chreo1.mp4
# video_resized:  /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Artur_05122021_chreo1_h920.mp4
# .mp4
# Processing video 1p_Artur_05122021_chreo1.mp4
# clip_name:  1p_Artur_05122021_chreo1.mp4
# video_name:  1p_Artur_05122021_chreo1  extention:  .mp4
# 920
# /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Artur_05122021_chreo1_h920.mp4
# Found the video_in
# Folder for resized video output: 1P_input_original /h 920
# The video has been resized previously
# Deleting old output files from the  output_op_1p 1p_Artur_05122021_chreo1  folder
#
#  Now the output folder contains only these files:
# []
# /content
# ['30/1']
# Number of frames per second:  30.0
#
#
# Video for Openpose /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Artur_05122021_chreo1_h920.mp4
# /bin/bash: ./build/examples/openpose/openpose.bin: No such file or directory
#
# ==============================
# Converting the stickfigure video to mp4
#
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# /content/gdrive/MyDrive/DSR/DanceApp/output_op_1p/1p_Artur_05122021_chreo1/openpose.avi: No such file or directory
# Something went wrong, as there was no output video from Openpose.
#
# Creating single frame images
# ==============================
#
#
# ==============================
# /content
# there are  0  json files to rename
#
# json are renamed
# ==============================
#
# video fullsize:  /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/1p_Earl_05122021_choreo1_flipped_lr.mp4
# video_resized:  /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Earl_05122021_choreo1_flipped_lr_h920.mp4
# .mp4
# Processing video 1p_Earl_05122021_choreo1_flipped_lr.mp4
# clip_name:  1p_Earl_05122021_choreo1_flipped_lr.mp4
# video_name:  1p_Earl_05122021_choreo1_flipped_lr  extention:  .mp4
# 920
# /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Earl_05122021_choreo1_flipped_lr_h920.mp4
# Found the video_in
# Folder for resized video output: 1P_input_original /h 920
# The video has been resized previously
# Deleting old output files from the  output_op_1p 1p_Earl_05122021_choreo1_flipped_lr  folder
#
#  Now the output folder contains only these files:
# []
# /content
# ['30/1']
# Number of frames per second:  30.0
#
#
# Video for Openpose /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Earl_05122021_choreo1_flipped_lr_h920.mp4
# /bin/bash: ./build/examples/openpose/openpose.bin: No such file or directory
#
# ==============================
# Converting the stickfigure video to mp4
#
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# /content/gdrive/MyDrive/DSR/DanceApp/output_op_1p/1p_Earl_05122021_choreo1_flipped_lr/openpose.avi: No such file or directory
# Something went wrong, as there was no output video from Openpose.
#
# Creating single frame images
# ==============================
#
#
# ==============================
# /content
# there are  0  json files to rename
#
# json are renamed
# ==============================
#
# video fullsize:  /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/1p_Eero_1_05122021_choreo1.mp4
# video_resized:  /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Eero_1_05122021_choreo1_h920.mp4
# .mp4
# Processing video 1p_Eero_1_05122021_choreo1.mp4
# clip_name:  1p_Eero_1_05122021_choreo1.mp4
# video_name:  1p_Eero_1_05122021_choreo1  extention:  .mp4
# 920
# /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Eero_1_05122021_choreo1_h920.mp4
# Found the video_in
# Folder for resized video output: 1P_input_original /h 920
# The video has been resized previously
# Deleting old output files from the  output_op_1p 1p_Eero_1_05122021_choreo1  folder
#
#  Now the output folder contains only these files:
# []
# /content
# ['88/3']
# Number of frames per second:  29.333333333333332
#
#
# Video for Openpose /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Eero_1_05122021_choreo1_h920.mp4
# /bin/bash: ./build/examples/openpose/openpose.bin: No such file or directory
#
# ==============================
# Converting the stickfigure video to mp4
#
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# /content/gdrive/MyDrive/DSR/DanceApp/output_op_1p/1p_Eero_1_05122021_choreo1/openpose.avi: No such file or directory
# Something went wrong, as there was no output video from Openpose.
#
# Creating single frame images
# ==============================
#
#
# ==============================
# /content
# there are  0  json files to rename
#
# json are renamed
# ==============================
#
# video fullsize:  /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/1p_Eero_4_05122021_choreo1.mp4
# video_resized:  /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Eero_4_05122021_choreo1_h920.mp4
# .mp4
# Processing video 1p_Eero_4_05122021_choreo1.mp4
# clip_name:  1p_Eero_4_05122021_choreo1.mp4
# video_name:  1p_Eero_4_05122021_choreo1  extention:  .mp4
# 920
# /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Eero_4_05122021_choreo1_h920.mp4
# Found the video_in
# Folder for resized video output: 1P_input_original /h 920
# The video has been resized previously
# Deleting old output files from the  output_op_1p 1p_Eero_4_05122021_choreo1  folder
#
#  Now the output folder contains only these files:
# []
# /content
# ['88/3']
# Number of frames per second:  29.333333333333332
#
#
# Video for Openpose /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Eero_4_05122021_choreo1_h920.mp4
# /bin/bash: ./build/examples/openpose/openpose.bin: No such file or directory
#
# ==============================
# Converting the stickfigure video to mp4
#
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# /content/gdrive/MyDrive/DSR/DanceApp/output_op_1p/1p_Eero_4_05122021_choreo1/openpose.avi: No such file or directory
# Something went wrong, as there was no output video from Openpose.
#
# Creating single frame images
# ==============================
#
#
# ==============================
# /content
# there are  0  json files to rename
#
# json are renamed
# ==============================
#
# video fullsize:  /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/1p_Eero_6_05122021_choreo1.mp4
# video_resized:  /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Eero_6_05122021_choreo1_h920.mp4
# .mp4
# Processing video 1p_Eero_6_05122021_choreo1.mp4
# clip_name:  1p_Eero_6_05122021_choreo1.mp4
# video_name:  1p_Eero_6_05122021_choreo1  extention:  .mp4
# 920
# /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Eero_6_05122021_choreo1_h920.mp4
# Found the video_in
# Folder for resized video output: 1P_input_original /h 920
# The video has been resized previously
# Deleting old output files from the  output_op_1p 1p_Eero_6_05122021_choreo1  folder
#
#  Now the output folder contains only these files:
# []
# /content
# ['88/3']
# Number of frames per second:  29.333333333333332
#
#
# Video for Openpose /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Eero_6_05122021_choreo1_h920.mp4
# /bin/bash: ./build/examples/openpose/openpose.bin: No such file or directory
#
# ==============================
# Converting the stickfigure video to mp4
#
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# /content/gdrive/MyDrive/DSR/DanceApp/output_op_1p/1p_Eero_6_05122021_choreo1/openpose.avi: No such file or directory
# Something went wrong, as there was no output video from Openpose.
#
# Creating single frame images
# ==============================
#
#
# ==============================
# /content
# there are  0  json files to rename
#
# json are renamed
# ==============================
#
# video fullsize:  /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/1p_Eero_7_05122021_choreo1.mp4
# video_resized:  /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Eero_7_05122021_choreo1_h920.mp4
# .mp4
# Processing video 1p_Eero_7_05122021_choreo1.mp4
# clip_name:  1p_Eero_7_05122021_choreo1.mp4
# video_name:  1p_Eero_7_05122021_choreo1  extention:  .mp4
# 920
# /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Eero_7_05122021_choreo1_h920.mp4
# Found the video_in
# Folder for resized video output: 1P_input_original /h 920
# The video has been resized previously
# Deleting old output files from the  output_op_1p 1p_Eero_7_05122021_choreo1  folder
#
#  Now the output folder contains only these files:
# []
# /content
# ['88/3']
# Number of frames per second:  29.333333333333332
#
#
# Video for Openpose /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Eero_7_05122021_choreo1_h920.mp4
# /bin/bash: ./build/examples/openpose/openpose.bin: No such file or directory
#
# ==============================
# Converting the stickfigure video to mp4
#
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# /content/gdrive/MyDrive/DSR/DanceApp/output_op_1p/1p_Eero_7_05122021_choreo1/openpose.avi: No such file or directory
# Something went wrong, as there was no output video from Openpose.
#
# Creating single frame images
# ==============================
#
#
# ==============================
# /content
# there are  0  json files to rename
#
# json are renamed
# ==============================
#
# video fullsize:  /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/1p_Dirk_choreo1_04.12.2021.mp4
# video_resized:  /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Dirk_choreo1_04.12.2021_h920.mp4
# .mp4
# Processing video 1p_Dirk_choreo1_04.12.2021.mp4
# clip_name:  1p_Dirk_choreo1_04.12.2021.mp4
# video_name:  1p_Dirk_choreo1_04.12.2021  extention:  .mp4
# 920
# /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Dirk_choreo1_04.12.2021_h920.mp4
# Found the video_in
# Folder for resized video output: 1P_input_original /h 920
# The video has been resized previously
# Deleting old output files from the  output_op_1p 1p_Dirk_choreo1_04.12.2021  folder
#
#  Now the output folder contains only these files:
# []
# /content
# ['30000/1001']
# Number of frames per second:  29.97002997002997
#
#
# Video for Openpose /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Dirk_choreo1_04.12.2021_h920.mp4
# /bin/bash: ./build/examples/openpose/openpose.bin: No such file or directory
#
# ==============================
# Converting the stickfigure video to mp4
#
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# /content/gdrive/MyDrive/DSR/DanceApp/output_op_1p/1p_Dirk_choreo1_04.12.2021/openpose.avi: No such file or directory
# Something went wrong, as there was no output video from Openpose.
#
# Creating single frame images
# ==============================
#
#
# ==============================
# /content
# there are  0  json files to rename
#
# json are renamed
# ==============================
#
# video fullsize:  /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/1p_Heidi_07122021_choreo1_-turns.MOV
# video_resized:  /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Heidi_07122021_choreo1_-turns_h920.mp4
# .mp4
# Processing video 1p_Heidi_07122021_choreo1_-turns.MOV
# clip_name:  1p_Heidi_07122021_choreo1_-turns.MOV
# video_name:  1p_Heidi_07122021_choreo1_-turns  extention:  .MOV
# 920
# /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Heidi_07122021_choreo1_-turns_h920.MOV
# Found the video_in
# Folder for resized video output: 1P_input_original /h 920
# The video has been resized previously
# Deleting old output files from the  output_op_1p 1p_Heidi_07122021_choreo1_-turns  folder
#
#  Now the output folder contains only these files:
# []
# /content
# ['60/1']
# Number of frames per second:  60.0
#
#
# Video for Openpose /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Heidi_07122021_choreo1_-turns_h920.MOV
# /bin/bash: ./build/examples/openpose/openpose.bin: No such file or directory
#
# ==============================
# Converting the stickfigure video to mp4
#
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# /content/gdrive/MyDrive/DSR/DanceApp/output_op_1p/1p_Heidi_07122021_choreo1_-turns/openpose.avi: No such file or directory
# Something went wrong, as there was no output video from Openpose.
#
# Creating single frame images
# ==============================
#
#
# ==============================
# /content
# there are  0  json files to rename
#
# json are renamed
# ==============================
#
# video fullsize:  /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/1p_JonathanB_05122021_choreo1.MOV
# video_resized:  /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_JonathanB_05122021_choreo1_h920.MOV
# .MOV
# Processing video 1p_JonathanB_05122021_choreo1.MOV
# clip_name:  1p_JonathanB_05122021_choreo1.MOV
# video_name:  1p_JonathanB_05122021_choreo1  extention:  .MOV
# 920
# /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_JonathanB_05122021_choreo1_h920.MOV
# Found the video_in
# Folder for resized video output: 1P_input_original /h 920
# The video has been resized previously
# Deleting old output files from the  output_op_1p 1p_JonathanB_05122021_choreo1  folder
#
#  Now the output folder contains only these files:
# []
# /content
# ['30000/1001']
# Number of frames per second:  29.97002997002997
#
#
# Video for Openpose /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_JonathanB_05122021_choreo1_h920.MOV
# /bin/bash: ./build/examples/openpose/openpose.bin: No such file or directory
#
# ==============================
# Converting the stickfigure video to mp4
#
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# /content/gdrive/MyDrive/DSR/DanceApp/output_op_1p/1p_JonathanB_05122021_choreo1/openpose.avi: No such file or directory
# Something went wrong, as there was no output video from Openpose.
#
# Creating single frame images
# ==============================
#
#
# ==============================
# /content
# there are  0  json files to rename
#
# json are renamed
# ==============================
#
# video fullsize:  /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/1P-Person1-whole.mp4
# video_resized:  /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1P-Person1-whole_h920.MOV
# .MOV
# Processing video 1P-Person1-whole.mp4
# clip_name:  1P-Person1-whole.mp4
# video_name:  1P-Person1-whole  extention:  .mp4
# 920
# /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1P-Person1-whole_h920.mp4
# Found the video_in
# Folder for resized video output: 1P_input_original /h 920
# The video has been resized previously
# Deleting old output files from the  output_op_1p 1P-Person1-whole  folder
#
#  Now the output folder contains only these files:
# []
# /content
# ['30/1']
# Number of frames per second:  30.0
#
#
# Video for Openpose /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1P-Person1-whole_h920.mp4
# /bin/bash: ./build/examples/openpose/openpose.bin: No such file or directory
#
# ==============================
# Converting the stickfigure video to mp4
#
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# /content/gdrive/MyDrive/DSR/DanceApp/output_op_1p/1P-Person1-whole/openpose.avi: No such file or directory
# Something went wrong, as there was no output video from Openpose.
#
# Creating single frame images
# ==============================
#
#
# ==============================
# /content
# there are  0  json files to rename
#
# json are renamed
# ==============================
#
# video fullsize:  /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/1p_Raquelinha_05122021_choreo1.mp4
# video_resized:  /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Raquelinha_05122021_choreo1_h920.mp4
# .mp4
# Processing video 1p_Raquelinha_05122021_choreo1.mp4
# clip_name:  1p_Raquelinha_05122021_choreo1.mp4
# video_name:  1p_Raquelinha_05122021_choreo1  extention:  .mp4
# 920
# /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Raquelinha_05122021_choreo1_h920.mp4
# Found the video_in
# Folder for resized video output: 1P_input_original /h 920
# The video has been resized previously
# Deleting old output files from the  output_op_1p 1p_Raquelinha_05122021_choreo1  folder
#
#  Now the output folder contains only these files:
# []
# /content
# ['23/1']
# Number of frames per second:  23.0
#
#
# Video for Openpose /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Raquelinha_05122021_choreo1_h920.mp4
# /bin/bash: ./build/examples/openpose/openpose.bin: No such file or directory
#
# ==============================
# Converting the stickfigure video to mp4
#
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# /content/gdrive/MyDrive/DSR/DanceApp/output_op_1p/1p_Raquelinha_05122021_choreo1/openpose.avi: No such file or directory
# Something went wrong, as there was no output video from Openpose.
#
# Creating single frame images
# ==============================
#
#
# ==============================
# /content
# there are  0  json files to rename
#
# json are renamed
# ==============================
#
# video fullsize:  /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/1p_sarah_salsa_basics_choreo1.mp4
# video_resized:  /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_sarah_salsa_basics_choreo1_h920.mp4
# .mp4
# Processing video 1p_sarah_salsa_basics_choreo1.mp4
# clip_name:  1p_sarah_salsa_basics_choreo1.mp4
# video_name:  1p_sarah_salsa_basics_choreo1  extention:  .mp4
# 920
# /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_sarah_salsa_basics_choreo1_h920.mp4
# Found the video_in
# Folder for resized video output: 1P_input_original /h 920
# The video has been resized previously
# Deleting old output files from the  output_op_1p 1p_sarah_salsa_basics_choreo1  folder
#
#  Now the output folder contains only these files:
# []
# /content
# ['30/1']
# Number of frames per second:  30.0
#
#
# Video for Openpose /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_sarah_salsa_basics_choreo1_h920.mp4
# /bin/bash: ./build/examples/openpose/openpose.bin: No such file or directory
#
# ==============================
# Converting the stickfigure video to mp4
#
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# /content/gdrive/MyDrive/DSR/DanceApp/output_op_1p/1p_sarah_salsa_basics_choreo1/openpose.avi: No such file or directory
# Something went wrong, as there was no output video from Openpose.
#
# Creating single frame images
# ==============================
#
#
# ==============================
# /content
# there are  0  json files to rename
#
# json are renamed
# ==============================
#
# video fullsize:  /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/1p_Stef_1_05122021_Choreo1.mp4
# video_resized:  /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Stef_1_05122021_Choreo1_h920.mp4
# .mp4
# Processing video 1p_Stef_1_05122021_Choreo1.mp4
# clip_name:  1p_Stef_1_05122021_Choreo1.mp4
# video_name:  1p_Stef_1_05122021_Choreo1  extention:  .mp4
# 920
# /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Stef_1_05122021_Choreo1_h920.mp4
# Found the video_in
# Folder for resized video output: 1P_input_original /h 920
# The video has been resized previously
# Deleting old output files from the  output_op_1p 1p_Stef_1_05122021_Choreo1  folder
#
#  Now the output folder contains only these files:
# []
# /content
# ['88/3']
# Number of frames per second:  29.333333333333332
#
#
# Video for Openpose /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Stef_1_05122021_Choreo1_h920.mp4
# /bin/bash: ./build/examples/openpose/openpose.bin: No such file or directory
#
# ==============================
# Converting the stickfigure video to mp4
#
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# /content/gdrive/MyDrive/DSR/DanceApp/output_op_1p/1p_Stef_1_05122021_Choreo1/openpose.avi: No such file or directory
# Something went wrong, as there was no output video from Openpose.
#
# Creating single frame images
# ==============================
#
#
# ==============================
# /content
# there are  0  json files to rename
#
# json are renamed
# ==============================
#
# video fullsize:  /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/1p_Stef_2_05122021_Choreo1.mp4
# video_resized:  /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Stef_2_05122021_Choreo1_h920.mp4
# .mp4
# Processing video 1p_Stef_2_05122021_Choreo1.mp4
# clip_name:  1p_Stef_2_05122021_Choreo1.mp4
# video_name:  1p_Stef_2_05122021_Choreo1  extention:  .mp4
# 920
# /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Stef_2_05122021_Choreo1_h920.mp4
# Found the video_in
# Folder for resized video output: 1P_input_original /h 920
# The video has been resized previously
# Deleting old output files from the  output_op_1p 1p_Stef_2_05122021_Choreo1  folder
#
#  Now the output folder contains only these files:
# []
# /content
# ['88/3']
# Number of frames per second:  29.333333333333332
#
#
# Video for Openpose /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Stef_2_05122021_Choreo1_h920.mp4
# /bin/bash: ./build/examples/openpose/openpose.bin: No such file or directory
#
# ==============================
# Converting the stickfigure video to mp4
#
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# /content/gdrive/MyDrive/DSR/DanceApp/output_op_1p/1p_Stef_2_05122021_Choreo1/openpose.avi: No such file or directory
# Something went wrong, as there was no output video from Openpose.
#
# Creating single frame images
# ==============================
#
#
# ==============================
# /content
# there are  0  json files to rename
#
# json are renamed
# ==============================
#
# video fullsize:  /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/1p_Stef_3_05122021_chroeo1.mp4
# video_resized:  /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Stef_3_05122021_chroeo1_h920.mp4
# .mp4
# Processing video 1p_Stef_3_05122021_chroeo1.mp4
# clip_name:  1p_Stef_3_05122021_chroeo1.mp4
# video_name:  1p_Stef_3_05122021_chroeo1  extention:  .mp4
# 920
# /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Stef_3_05122021_chroeo1_h920.mp4
# Found the video_in
# Folder for resized video output: 1P_input_original /h 920
# The video has been resized previously
# Deleting old output files from the  output_op_1p 1p_Stef_3_05122021_chroeo1  folder
#
#  Now the output folder contains only these files:
# []
# /content
# ['88/3']
# Number of frames per second:  29.333333333333332
#
#
# Video for Openpose /content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Stef_3_05122021_chroeo1_h920.mp4
# /bin/bash: ./build/examples/openpose/openpose.bin: No such file or directory
#
# ==============================
# Converting the stickfigure video to mp4
#
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# /content/gdrive/MyDrive/DSR/DanceApp/output_op_1p/1p_Stef_3_05122021_chroeo1/openpose.avi: No such file or directory
# Something went wrong, as there was no output video from Openpose.
#
# Creating single frame images
# ==============================
#
#
# ==============================
# /content
# there are  0  json files to rename
#
# json are renamed
# ==============================

# %%
os.path.isfile("/content/gdrive/MyDrive/DSR/DanceApp/1P_input_original/h920/1p_Eero_1_05122021_choreo1_h920.mp4")
# Out:
# True

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section
